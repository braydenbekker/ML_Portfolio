# %% [markdown]
# # Simple Linear Regression

# %%
"""
Similar to the other scripts in this repository, the purpose of this project is to create the most complete 
walkthrough of the topic in 30 minutes without using outside resources.

The topic here is Simple Linear Regression

Date 11/2/2023
"""

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df_in = pd.read_csv('train.csv')
"""
Will Cukierski. (2012). Titanic - Machine Learning from Disaster. Kaggle. https://kaggle.com/competitions/titanic
"""
# Out:
# '\nWill Cukierski. (2012). Titanic - Machine Learning from Disaster. Kaggle. https://kaggle.com/competitions/titanic\n'

# %%
"""
Plan:
1) Clean the dataset by removing nan values
2) Check premodel assumptions of linearity and normality with scatterplot matrix using pairplot.
3) Identify a variable that meets these criteria with the column 'Suvived'
4) Create an model using Ordinary Least Squares
5) Check the post model assumptions of homoscedacity and independent observations.
6) Print the model summary
7) Discuss the results
"""

# %%
df_in.isna().any(axis=1).sum()
# Out:
# 708

# %%
#Identifying the problem feature(s)

# %%
df_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_in.drop(['Cabin', 'Age'], axis=1, inplace=True)

# %%
df_in.isna().any(axis=1).sum()
# Out:
# 2

# %%
df=df_in.dropna(axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   SibSp        889 non-null    int64
#  6   Parch        889 non-null    int64
#  7   Ticket       889 non-null    object
#  8   Fare         889 non-null    float64
#  9   Embarked     889 non-null    object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 76.4+ KB

# %%
sns.pairplot(df)
